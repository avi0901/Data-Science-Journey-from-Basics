# %% [markdown]
# https://app.swaggerhub.com/apis-docs/Vivek-Raj/zomato-api/1.0.0
#
#
# Since you would not be able to use the official website to generate your own access key, for now use any of the following user keys:
#
# 627c28c07ad221c65491bbffea6f5d54
#
# 68a952b60155797d28def1585d888b9f
#
# a1460684c45b3ba1a38a6b1473597055
#
# 399720f6f904f106e162cd2bd0011a6f
#
# 816c8c7a9e52da5bd2dcc0446558288d

# %%
import requests
headers = {'user-key': '1916a1cbf9ae3cca094d599c14b5bd23'}
url = "https://developers.zomato.com/api/v2.1"
info  = {'city_ids':'280'}
response = requests.get(url+'/cities',headers=headers,params = info)
cities = response.json()
cities
# Out:
# {'location_suggestions': [{'id': 280,
#    'name': 'New York City, NY',
#    'country_id': 216,
#    'country_name': 'United States',
#    'country_flag_url': 'https://b.zmtcdn.com/images/countries/flags/country_216.png',
#    'should_experiment_with': 0,
#    'has_go_out_tab': 0,
#    'discovery_enabled': 1,
#    'has_new_ad_format': 0,
#    'is_state': 0,
#    'state_id': 103,
#    'state_name': 'New York State',
#    'state_code': 'NY'}],
#  'status': 'success',
#  'has_more': 0,
#  'has_total': 0,
#  'user_has_addresses': True}

# %%
import requests
headers = {'user-key': '1916a1cbf9ae3cca094d599c14b5bd23'}
url = "https://developers.zomato.com/api/v2.1"
info  = {'query':'Raigarh'}
response = requests.get(url+'/locations',headers=headers,params = info)
cities = response.json()
cities
# Out:
# {'location_suggestions': [{'entity_type': 'city',
#    'entity_id': 11482,
#    'title': 'Raigarh',
#    'latitude': 21.8974,
#    'longitude': 83.395,
#    'city_id': 11482,
#    'city_name': 'Raigarh',
#    'country_id': 1,
#    'country_name': 'India'}],
#  'status': 'success',
#  'has_more': 0,
#  'has_total': 0,
#  'user_has_addresses': True}

# %%
import requests
headers = {'user-key': '1916a1cbf9ae3cca094d599c14b5bd23'}
url = "https://developers.zomato.com/api/v2.1"
info  = {'city_id':'11482'}
response = requests.get(url+'/establishments',headers=headers,params = info)
cities = response.json()
cities
# Out:
# {'establishments': [{'establishment': {'id': 16, 'name': 'Casual Dining'}},
#   {'establishment': {'id': 18, 'name': 'Fine Dining'}},
#   {'establishment': {'id': 307, 'name': 'Bhojanalya'}},
#   {'establishment': {'id': 31, 'name': 'Bakery'}},
#   {'establishment': {'id': 1, 'name': 'Café'}},
#   {'establishment': {'id': 21, 'name': 'Quick Bites'}},
#   {'establishment': {'id': 191, 'name': 'Confectionery'}},
#   {'establishment': {'id': 61, 'name': 'Dhaba'}},
#   {'establishment': {'id': 20, 'name': 'Food Court'}},
#   {'establishment': {'id': 291, 'name': 'Sweet Shop'}},
#   {'establishment': {'id': 23, 'name': 'Dessert Parlour'}},
#   {'establishment': {'id': 41, 'name': 'Beverage Shop'}},
#   {'establishment': {'id': 4, 'name': 'Kiosk'}},
#   {'establishment': {'id': 311, 'name': 'General Store'}}]}

# %%
import requests
headers = {'user-key': '1916a1cbf9ae3cca094d599c14b5bd23'}
url = "https://developers.zomato.com/api/v2.1"
info  = {}
response = requests.get(url+'/search',headers=headers,params = info)
cities = response.json()
cities
# Out:
# {'results_found': 1570880,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'res_id': 19671477,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#     'apikey': '1916a1cbf9ae3cca094d599c14b5bd23',
#     'id': '19671477',
#     'name': 'Osteria 44',
#     'url': 'https://www.zomato.com/coimbra/osteria-44-santo-antonio-dos-olivais?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Rua O Conimbricense, 44-46, Santo Antonio Dos Olivais, Coimbra',
#      'locality': 'Santo Antonio Dos Olivais',
#      'city': 'Coimbra',
#      'city_id': 11904,
#      'latitude': '40.1832773694',
#      'longitude': '-8.4060034602',
#      'zipcode': '',
#      'country_id': 164,
#      'locality_verbose': 'Santo Antonio Dos Olivais, Coimbra'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Italian',
# ...

# %%
import requests
headers = {'user-key': '1916a1cbf9ae3cca094d599c14b5bd23'}
url = "https://developers.zomato.com/api/v2.1"
info  = {'q':'Indore'}
response = requests.get(url+'/cities',headers=headers,params = info)
cities = response.json()
cities
# Out:
# {'location_suggestions': [{'id': 14,
#    'name': 'Indore',
#    'country_id': 1,
#    'country_name': 'India',
#    'country_flag_url': 'https://b.zmtcdn.com/images/countries/flags/country_1.png',
#    'should_experiment_with': 0,
#    'has_go_out_tab': 0,
#    'discovery_enabled': 0,
#    'has_new_ad_format': 1,
#    'is_state': 0,
#    'state_id': 0,
#    'state_name': '',
#    'state_code': ''}],
#  'status': 'success',
#  'has_more': 0,
#  'has_total': 0,
#  'user_has_addresses': True}

# %%
import requests
headers = {'user-key': '1916a1cbf9ae3cca094d599c14b5bd23'}
url = "https://developers.zomato.com/api/v2.1"
info  = {'city_id':'11482'}
response = requests.get(url+'/cuisines',headers=headers,params = info)
cities = response.json()
cities
# Out:
# {'cuisines': [{'cuisine': {'cuisine_id': 5, 'cuisine_name': 'Bakery'}},
#   {'cuisine': {'cuisine_id': 270, 'cuisine_name': 'Beverages'}},
#   {'cuisine': {'cuisine_id': 7, 'cuisine_name': 'Biryani'}},
#   {'cuisine': {'cuisine_id': 168, 'cuisine_name': 'Burger'}},
#   {'cuisine': {'cuisine_id': 30, 'cuisine_name': 'Cafe'}},
#   {'cuisine': {'cuisine_id': 994, 'cuisine_name': 'Charcoal Chicken'}},
#   {'cuisine': {'cuisine_id': 25, 'cuisine_name': 'Chinese'}},
#   {'cuisine': {'cuisine_id': 35, 'cuisine_name': 'Continental'}},
#   {'cuisine': {'cuisine_id': 1014, 'cuisine_name': 'Cuisine Varies'}},
#   {'cuisine': {'cuisine_id': 100, 'cuisine_name': 'Desserts'}},
#   {'cuisine': {'cuisine_id': 40, 'cuisine_name': 'Fast Food'}},
#   {'cuisine': {'cuisine_id': 48, 'cuisine_name': 'Gujarati'}},
#   {'cuisine': {'cuisine_id': 143, 'cuisine_name': 'Healthy Food'}},
#   {'cuisine': {'cuisine_id': 49, 'cuisine_name': 'Hyderabadi'}},
# ...

# %% [markdown]
# ## Biryani Raigarh

# %%
import requests
headers = {'user-key': '1916a1cbf9ae3cca094d599c14b5bd23'}
url = "https://developers.zomato.com/api/v2.1"
info  = {'entity_id':'11482','entity_type':'city','sort':'rating','cuisines':[7],'order':'dsc','count':10}
response = requests.get(url+'/search',headers=headers,params = info)
cities = response.json()
restaurants = cities['restaurants']
restaurants
# Out:
# [{'restaurant': {'R': {'res_id': 19016475,
#     'is_grocery_store': False,
#     'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#    'apikey': '1916a1cbf9ae3cca094d599c14b5bd23',
#    'id': '19016475',
#    'name': 'Aamantran Restaurant',
#    'url': 'https://www.zomato.com/raigarh/aamantran-restaurant-raigarh-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': 'Ward 23, Hemu Kalani Chowk, Near Kelo Bridge, Raigarh Locality, Rajgarh',
#     'locality': 'Raigarh Locality',
#     'city': 'Raigarh',
#     'city_id': 11482,
#     'latitude': '21.8919623543',
#     'longitude': '83.4016770613',
#     'zipcode': '',
#     'country_id': 1,
#     'locality_verbose': 'Raigarh Locality, Raigarh'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Biryani, North Indian, Sandwich',
#    'timings': '8:30 AM to 11 PM',
#    'average_cost_for_two': 300,
#    'price_range': 1,
#    'currency': 'Rs.',
#    'highlights': ['Delivery',
# ...

# %%
for i in restaurants :
    x = i['restaurant']['name']
    y = i['restaurant']['cuisines']
    print(x, ' : ' ,y )
# Out:
# Aamantran Restaurant  :  Biryani, North Indian, Sandwich
# J K Restaurant  :  Biryani, North Indian, Chinese
# SUSHRI RESTAURENT   :  South Indian, North Indian, Mithai, Fast Food, Desserts, Chinese, Biryani
# Hotel KGN  :  North Indian, Biryani
# IMLY Restaurant   :  South Indian, North Indian, Fast Food, Chinese, Biryani
# Hotel KGN  :  Biryani, North Indian, Sandwich
# HOTEL MEZBAAN  :  Biryani, North Indian, Mughlai
# Hydrabad Briyani Point   :  Roast Chicken, North Indian, Biryani, Chinese, Fast Food, Hyderabadi, Street Food
# Farm house kitchen- New Alankar.  :  North Indian, Fast Food, Biryani
# Lazeez Biryani  :  Biryani, North Indian

# %% [markdown]
# ## Momos Raigarh

# %%
import requests
headers = {'user-key': '1916a1cbf9ae3cca094d599c14b5bd23'}
url = "https://developers.zomato.com/api/v2.1"
info  = {'entity_id':'11482','entity_type':'city','sort':'rating','cuisines':[1051],'order':'dsc','count':10}
response = requests.get(url+'/search',headers=headers,params = info)
cities = response.json()
restaurants = cities['restaurants']
for i in restaurants :
    x = i['restaurant']['name']
    y = i['restaurant']['cuisines']
    print(x, ' : ' ,y )
# Out:
# Jenny Di Momos Corner  :  Chinese, Momos, Italian
# Delhi Zaika Kathi Roll And Momos  :  Momos, Rolls

# %%
import requests
headers = {'user-key': '1916a1cbf9ae3cca094d599c14b5bd23'}
url = "https://developers.zomato.com/api/v2.1"
info  = {'query':'Indore'}
response = requests.get(url+'/locations',headers=headers,params = info)
cities = response.json()
cities
# Out:
# {'location_suggestions': [{'entity_type': 'city',
#    'entity_id': 14,
#    'title': 'Indore',
#    'latitude': 22.7252,
#    'longitude': 75.857,
#    'city_id': 14,
#    'city_name': 'Indore',
#    'country_id': 1,
#    'country_name': 'India'}],
#  'status': 'success',
#  'has_more': 0,
#  'has_total': 0,
#  'user_has_addresses': True}

# %%
import requests
headers = {'user-key': '1916a1cbf9ae3cca094d599c14b5bd23'}
url = "https://developers.zomato.com/api/v2.1"
info  = {'entity_id':'14','entity_type':'city','sort':'rating','cuisines':[7],'order':'dsc','count':10}
response = requests.get(url+'/search',headers=headers,params = info)
cities = response.json()
restaurants = cities['restaurants']
for i in restaurants :
    x = i['restaurant']['name']
    y = i['restaurant']['cuisines']
    print(x, ' : ' ,y )
# Out:
# Kebabsville - Sayaji Hotel  :  North Indian, Bar Food
# Cravings - Sayaji Hotel  :  North Indian, Chinese, Italian
# The Cube - Hotel Effotel  :  North Indian, Chinese, Italian
# Hotel Shreemaya  :  North Indian, Chinese
# Bollywood Theka  :  Finger Food, North Indian, Fast Food, Chinese
# Stars N Sky  :  North Indian, Chinese, Mughlai
# Banana Leaf  :  South Indian, North Indian, Desserts, Beverages
# Behrouz Biryani  :  Biryani, North Indian, Mughlai, Kebab
# 54 Praangan - Indore Marriott Hotel  :  Awadhi, North Indian
# Al-Fazl Biryani  :  Biryani
